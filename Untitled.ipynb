# %%
import imaplib
import email
from email.header import decode_header
import webbrowser
import os
from bs4 import BeautifulSoup
from datetime import datetime, timedelta, date
import math
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import json
import config

# %%
username = config.EMAIL_USERNAME
password = config.APP_PASSWORD
from_email = config.EMAIL_FROM

imap_server = "imap.gmail.com"

# %%
class Shift:
    def __init__(self, date, day, start_time, end_time, hours_worked):
        # Ensure date is stored as datetime.date object
        self.date = datetime.strptime(date, '%d/%m/%Y').date()
        self.day = day
        self.start_time = self.parse_time(start_time)
        self.end_time = self.parse_time(end_time)
        self.hours_worked = hours_worked
        self.hourly_rate = 40
        self.shift_conditions = self.load_shift_conditions()
        self.shift_type = self.classify_hours()
        self.hours_breakdown = self.calculate_hours_breakdown()
    
    def load_shift_conditions(self):
        with open('shift_conditions.json', 'r', encoding='utf-8') as file:
            shift_conditions = json.load(file)
        return shift_conditions
        
    def calculate_hours_breakdown(self):
        breakdown = {'regular': '00:00', 'overtime_125': '00:00', 'overtime_150': '00:00'}
        if 'night' in self.shift_type:
            # Night shift special logic
            hours_threshold = {'regular': 7 * 60, 'overtime_125': 10 * 60, 'overtime_150': 12 * 60}
        else:
            # Regular shift logic
            hours_threshold = {'regular': 8 * 60, 'overtime_125': 10 * 60, 'overtime_150': 12 * 60}
            
            
        if not (self.start_time and self.end_time and self.hours_worked):
            # No work or incomplete data, no breakdown
            return breakdown


        work_minutes = int(self.hours_worked.split(':')[0]) * 60 + int(self.hours_worked.split(':')[1])

        if work_minutes <= hours_threshold['regular']:
            breakdown['regular'] = self.format_hours(work_minutes)
        elif work_minutes <= hours_threshold['overtime_125']:
            breakdown['regular'] = self.format_hours(hours_threshold['regular'])
            breakdown['overtime_125'] = self.format_hours(work_minutes - hours_threshold['regular'])
        else:
            breakdown['regular'] = self.format_hours(hours_threshold['regular'])
            breakdown['overtime_125'] = self.format_hours(120)
            breakdown['overtime_150'] = self.format_hours(work_minutes - hours_threshold['overtime_125'])

        return breakdown

    def format_hours(self, minutes):
        hours, remainder = divmod(minutes, 60)
        return f"{hours:02d}:{remainder:02d}"

    def parse_time(self, time_str):
        try:
            return datetime.strptime(time_str, '%H:%M')
        except ValueError:
            return None

    def map_hebrew_to_english(self, hebrew_day):
        hebrew_to_english_mapping = {
            "א": "Sun",
            "ב": "Mon",
            "ג": "Tue",
            "ד": "Wed",
            "ה": "Thu",
            "ו": "Fri",
            "ש": "Sat"
        }
        return hebrew_to_english_mapping.get(hebrew_day, hebrew_day)

    def check_custom_shift_conditions(self, custom_shift):
        date_start = datetime.strptime(custom_shift['date_start'], '%Y-%m-%d').date()
        date_end = datetime.strptime(custom_shift['date_end'], '%Y-%m-%d').date()

        # Convert self.date to datetime.date for comparison
        self_date = datetime(self.date.year, self.date.month, self.date.day).date()

        if date_start <= self_date <= date_end:
            # Map Hebrew day to English day
            english_day = self.map_hebrew_to_english(self.day)

            # Check day conditions
            if english_day in custom_shift['day_conditions']:
                # Check time slots
                for time_slot in custom_shift['time_slots']:
                    if time_slot['start'] <= self.start_time.hour < time_slot['end']:
                        # Handle the absence of 'base_hours' key for each time slot
                        return time_slot.get('base_hours', 0)

        return None

    def classify_hours(self):
        if self.start_time is None or self.end_time is None:
            return {'unclassified': '0:00'}

        shift_types = {
            'morning': {'start': 7, 'end': 15, 'base_hours': 8, 'days': ["Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat"]},
            'night': {'start': 15, 'end': 23, 'base_hours': 8, 'days': ["Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat"]},
            'overnight': {'start': 23, 'end': 7, 'base_hours': 7, 'days': ["Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat"]}
        }

        custom_shift_results = {}

        # Check for custom shifts
        for custom_shift in self.shift_conditions['custom_shifts']:
            result = self.check_custom_shift_conditions(custom_shift)
            if result is not None:
                custom_shift_results[custom_shift['name']] = result

        if custom_shift_results:
            # Choose the custom shift with the highest base hours
            max_custom_shift = max(custom_shift_results, key=lambda x: custom_shift_results[x])
            return {max_custom_shift: custom_shift_results[max_custom_shift]}

        # Convert Hebrew day to English day
        english_day = self.map_hebrew_to_english(self.day)

        # Check if the start time is exactly on the boundary between shifts
        for shift_type, shift_data in shift_types.items():
            if shift_data['start'] <= self.start_time.hour < shift_data['end'] and english_day in shift_data['days']:
                return {shift_type: shift_data['base_hours']}

        # If not within any shift boundary, choose the closest shift
        closest_shift_type = min(shift_types.keys(), key=lambda x: abs(self.start_time.hour - shift_types[x]['start']))
        shift_data = shift_types[closest_shift_type]

        return {closest_shift_type: shift_data['base_hours']}
    
    def calculate_shift_earnings(self):
        regular_earnings = self.calculate_earnings(self.hours_breakdown['regular'], self.hourly_rate * 1)
        overtime_125_earnings = self.calculate_earnings(self.hours_breakdown['overtime_125'], self.hourly_rate * 1.25)
        overtime_150_earnings = self.calculate_earnings(self.hours_breakdown['overtime_150'], self.hourly_rate * 1.50)

        return {
            'regular_earnings': regular_earnings,
            'overtime_125_earnings': overtime_125_earnings,
            'overtime_150_earnings': overtime_150_earnings
        }

    def calculate_earnings(self, hours_worked, hourly_rate):
        hours, minutes = map(int, hours_worked.split(':'))
        total_hours = hours + minutes / 60
        return total_hours * hourly_rate

# %%
class User:
    def __init__(self, shifts):
        self.shifts = shifts

    @classmethod
    def from_email_message(cls, email_message):
        shifts = []

        for part in email_message.walk():
            if part.get_content_type() == "text/html":
                soup = BeautifulSoup(part.get_payload(decode=True), 'html.parser')
                table = soup.find('table')

                if table:
                    for row in table.find_all('tr'):
                        columns = row.find_all(['td', 'th'])
                        row_data = [col.get_text(strip=True) for col in columns]

                        if len(row_data) == 4:  # Ensure it's a valid row with all necessary data
                            date, day, time_range, hours_worked = row_data
                            start_time, end_time = map(lambda x: x.strip(), time_range.split('-'))
                            shift = Shift(date, day, start_time, end_time, hours_worked)
                            shifts.append(shift)

        return cls(shifts)

    def calculate_monthly_earnings(self):
        total_earnings = {'regular': 0, 'overtime_125': 0, 'overtime_150': 0, 'total': 0}

        for shift in self.shifts:
            if shift.start_time and shift.end_time:
                shift_earnings = shift.calculate_shift_earnings()
                total_earnings['regular'] += round(shift_earnings['regular_earnings'],2)
                total_earnings['overtime_125'] += round(shift_earnings['overtime_125_earnings'],2)
                total_earnings['overtime_150'] += round(shift_earnings['overtime_150_earnings'],2)
                total_earnings['total'] += round(sum(shift_earnings.values()),2)

        return total_earnings

# %%
mail = imaplib.IMAP4_SSL(imap_server)

# %%
mail.login(username, password)
# Out:
# ('OK', [b'dkvitca@gmail.com authenticated (Success)'])

# %%
mail.select("INBOX")
# Out:
# ('OK', [b'10280'])

# %%
_, selected_mails = mail.search(None, f'(FROM "{from_email}")')

# %%
latest_email_id = selected_mails[0].split()[-1]

_, data = mail.fetch(latest_email_id, '(RFC822)')
_, bytes_data = data[0]

# Convert the byte data to message
email_message = email.message_from_bytes(bytes_data)

# %%
# Create User instance and process email data
user = User.from_email_message(email_message)

for shift in user.shifts:
    shift_earnings = shift.calculate_shift_earnings()
    if shift.start_time and shift.end_time:
        print(
            f"{shift.date}, {shift.start_time.strftime('%H:%M')}, "
            f"{shift.end_time.strftime('%H:%M')}, {shift.hours_worked} hours, "
            f"Hours Breakdown: {shift.hours_breakdown}, "
            f"Earnings: Regular: {shift_earnings['regular_earnings']:.2f} Shekels, "
            f"Overtime 125: {shift_earnings['overtime_125_earnings']:.2f} Shekels, "
            f"Overtime 150: {shift_earnings['overtime_150_earnings']:.2f} Shekels, "
            f"Total: {sum(shift_earnings.values()):.2f} Shekels, "
            f"shift type: {shift.shift_type}"
        )

        # Print custom shift information if applicable
        if 'unclassified' not in shift.shift_type:
            print(f"Shift Type: {shift.shift_type}")
        else:
            print(f"Shift Type: Unclassified")

    else:
        print(f"{shift.date}, No work on this day")
# Out:
# 2023-11-01, 07:50, 19:10, 11:20 hours, Hours Breakdown: {'regular': '08:00', 'overtime_125': '02:00', 'overtime_150': '01:20'}, Earnings: Regular: 320.00 Shekels, Overtime 125: 100.00 Shekels, Overtime 150: 80.00 Shekels, Total: 500.00 Shekels, shift type: {'morning': 8}
# Shift Type: {'morning': 8}
# 2023-11-02, 07:05, 14:55, 07:50 hours, Hours Breakdown: {'regular': '07:50', 'overtime_125': '00:00', 'overtime_150': '00:00'}, Earnings: Regular: 313.33 Shekels, Overtime 125: 0.00 Shekels, Overtime 150: 0.00 Shekels, Total: 313.33 Shekels, shift type: {'morning': 8}
# Shift Type: {'morning': 8}
# 2023-11-03, 22:50, 07:10, 08:20 hours, Hours Breakdown: {'regular': '07:00', 'overtime_125': '01:20', 'overtime_150': '00:00'}, Earnings: Regular: 280.00 Shekels, Overtime 125: 66.67 Shekels, Overtime 150: 0.00 Shekels, Total: 346.67 Shekels, shift type: {'night': 8}
# Shift Type: {'night': 8}
# 2023-11-04, No work on this day
# 2023-11-05, 14:39, 23:05, 08:26 hours, Hours Breakdown: {'regular': '08:00', 'overtime_125': '00:26', 'overtime_150': '00:00'}, Earnings: Regular: 320.00 Shekels, Overtime 125: 21.67 Shekels, Overtime 150: 0.00 Shekels, Total: 341.67 Shekels, shift type: {'morning': 8}
# Shift Type: {'morning': 8}
# 2023-11-06, 22:50, 07:05, 08:15 hours, Hours Breakdown: {'regular': '07:00', 'overtime_125': '01:15', 'overtime_150': '00:00'}, Earnings: Regular: 280.00 Shekels, Overtime 125: 62.50 Shekels, Overtime 150: 0.00 Shekels, Total: 342.50 Shekels, shift type: {'night': 8}
# Shift Type: {'night': 8}
# 2023-11-07, No work on this day
# 2023-11-08, 14:30, 23:10, 08:40 hours, Hours Breakdown: {'regular': '08:00', 'overtime_125': '00:40', 'overtime_150': '00:00'}, Earnings: Regular: 320.00 Shekels, Overtime 125: 33.33 Shekels, Overtime 150: 0.00 Shekels, Total: 353.33 Shekels, shift type: {'morning': 8}
# Shift Type: {'morning': 8}
# 2023-11-09, 14:50, 23:50, 09:00 hours, Hours Breakdown: {'regular': '08:00', 'overtime_125': '01:00', 'overtime_150': '00:00'}, Earnings: Regular: 320.00 Shekels, Overtime 125: 50.00 Shekels, Overtime 150: 0.00 Shekels, Total: 370.00 Shekels, shift type: {'morning': 8}
# Shift Type: {'morning': 8}
# 2023-11-10, 15:00, 23:31, 08:31 hours, Hours Breakdown: {'regular': '08:00', 'overtime_125': '00:31', 'overtime_150': '00:00'}, Earnings: Regular: 320.00 Shekels, Overtime 125: 25.83 Shekels, Overtime 150: 0.00 Shekels, Total: 345.83 Shekels, shift type: {'custom_shift_1': 17}
# Shift Type: {'custom_shift_1': 17}
# 2023-11-11, 22:41, 07:13, 08:32 hours, Hours Breakdown: {'regular': '07:00', 'overtime_125': '01:32', 'overtime_150': '00:00'}, Earnings: Regular: 280.00 Shekels, Overtime 125: 76.67 Shekels, Overtime 150: 0.00 Shekels, Total: 356.67 Shekels, shift type: {'night': 8}
# Shift Type: {'night': 8}
# 2023-11-12, No work on this day
# 2023-11-13, 14:50, 23:01, 08:11 hours, Hours Breakdown: {'regular': '08:00', 'overtime_125': '00:11', 'overtime_150': '00:00'}, Earnings: Regular: 320.00 Shekels, Overtime 125: 9.17 Shekels, Overtime 150: 0.00 Shekels, Total: 329.17 Shekels, shift type: {'morning': 8}
# Shift Type: {'morning': 8}
# 2023-11-14, 11:00, 22:49, 11:49 hours, Hours Breakdown: {'regular': '08:00', 'overtime_125': '02:00', 'overtime_150': '01:49'}, Earnings: Regular: 320.00 Shekels, Overtime 125: 100.00 Shekels, Overtime 150: 109.00 Shekels, Total: 529.00 Shekels, shift type: {'morning': 8}
# Shift Type: {'morning': 8}
# 2023-11-15, 13:21, 23:03, 09:42 hours, Hours Breakdown: {'regular': '08:00', 'overtime_125': '01:42', 'overtime_150': '00:00'}, Earnings: Regular: 320.00 Shekels, Overtime 125: 85.00 Shekels, Overtime 150: 0.00 Shekels, Total: 405.00 Shekels, shift type: {'morning': 8}
# Shift Type: {'morning': 8}
# 2023-11-16, No work on this day
# 2023-11-17, No work on this day
# 2023-11-18, 22:50, 07:13, 08:23 hours, Hours Breakdown: {'regular': '07:00', 'overtime_125': '01:23', 'overtime_150': '00:00'}, Earnings: Regular: 280.00 Shekels, Overtime 125: 69.17 Shekels, Overtime 150: 0.00 Shekels, Total: 349.17 Shekels, shift type: {'night': 8}
# Shift Type: {'night': 8}
# 2023-11-19, No work on this day
# 2023-11-20, 10:54, 23:01, 12:07 hours, Hours Breakdown: {'regular': '08:00', 'overtime_125': '02:00', 'overtime_150': '02:07'}, Earnings: Regular: 320.00 Shekels, Overtime 125: 100.00 Shekels, Overtime 150: 127.00 Shekels, Total: 547.00 Shekels, shift type: {'morning': 8}
# Shift Type: {'morning': 8}
# 2023-11-21, 10:59, 22:59, 12:00 hours, Hours Breakdown: {'regular': '08:00', 'overtime_125': '02:00', 'overtime_150': '02:00'}, Earnings: Regular: 320.00 Shekels, Overtime 125: 100.00 Shekels, Overtime 150: 120.00 Shekels, Total: 540.00 Shekels, shift type: {'morning': 8}
# Shift Type: {'morning': 8}
# 2023-11-22, 22:50, 06:57, 08:07 hours, Hours Breakdown: {'regular': '07:00', 'overtime_125': '01:07', 'overtime_150': '00:00'}, Earnings: Regular: 280.00 Shekels, Overtime 125: 55.83 Shekels, Overtime 150: 0.00 Shekels, Total: 335.83 Shekels, shift type: {'night': 8}
# Shift Type: {'night': 8}
# 2023-11-23, No work on this day
# 2023-11-24, 06:15, 15:10, 08:55 hours, Hours Breakdown: {'regular': '08:00', 'overtime_125': '00:55', 'overtime_150': '00:00'}, Earnings: Regular: 320.00 Shekels, Overtime 125: 45.83 Shekels, Overtime 150: 0.00 Shekels, Total: 365.83 Shekels, shift type: {'custom_shift_1': 17}
# Shift Type: {'custom_shift_1': 17}
# 2023-11-25, 07:17, 14:21, 07:04 hours, Hours Breakdown: {'regular': '07:04', 'overtime_125': '00:00', 'overtime_150': '00:00'}, Earnings: Regular: 282.67 Shekels, Overtime 125: 0.00 Shekels, Overtime 150: 0.00 Shekels, Total: 282.67 Shekels, shift type: {'custom_shift_1': 17}
# Shift Type: {'custom_shift_1': 17}
# 2023-11-26, 07:08, 14:56, 07:48 hours, Hours Breakdown: {'regular': '07:48', 'overtime_125': '00:00', 'overtime_150': '00:00'}, Earnings: Regular: 312.00 Shekels, Overtime 125: 0.00 Shekels, Overtime 150: 0.00 Shekels, Total: 312.00 Shekels, shift type: {'morning': 8}
# Shift Type: {'morning': 8}
# 2023-11-27, 22:45, 06:55, 08:10 hours, Hours Breakdown: {'regular': '07:00', 'overtime_125': '01:10', 'overtime_150': '00:00'}, Earnings: Regular: 280.00 Shekels, Overtime 125: 58.33 Shekels, Overtime 150: 0.00 Shekels, Total: 338.33 Shekels, shift type: {'night': 8}
# Shift Type: {'night': 8}
# 2023-11-28, No work on this day
# 2023-11-29, 13:40, 23:20, 09:40 hours, Hours Breakdown: {'regular': '08:00', 'overtime_125': '01:40', 'overtime_150': '00:00'}, Earnings: Regular: 320.00 Shekels, Overtime 125: 83.33 Shekels, Overtime 150: 0.00 Shekels, Total: 403.33 Shekels, shift type: {'morning': 8}
# Shift Type: {'morning': 8}
# 2023-11-30, 14:50, 22:32, 07:42 hours, Hours Breakdown: {'regular': '07:42', 'overtime_125': '00:00', 'overtime_150': '00:00'}, Earnings: Regular: 308.00 Shekels, Overtime 125: 0.00 Shekels, Overtime 150: 0.00 Shekels, Total: 308.00 Shekels, shift type: {'morning': 8}
# Shift Type: {'morning': 8}

# %%
# Generate HTML table
html_table = """
<html>
<head>
<style>
    table {
        font-family: Arial, sans-serif;
        border-collapse: collapse;
        width: 100%;
    }

    th, td {
        border: 1px solid #dddddd;
        text-align: left;
        padding: 8px;
    }

    th {
        background-color: #f2f2f2;
    }

    tfoot td {
        font-weight: bold;
    }
</style>
</head>
<body>

<table>
    <thead>
        <tr>
            <th>Date</th>
            <th>Shift Type</th>
            <th>Start Time</th>
            <th>End Time</th>
            <th>Hours Worked</th>
            <th>100%</th>
            <th>125%</th>
            <th>150%</th>
            <th>100% Revenue</th>
            <th>125% Revenue</th>
            <th>150% Revenue</th>
        </tr>
    </thead>
    <tbody>
"""

for shift in user.shifts:
    shift_earnings = shift.calculate_shift_earnings()
    if shift.start_time and shift.end_time:
        html_table += (
            f"<tr>"
            f"<td>{shift.date}</td>"
            f"<td>{list(shift.shift_type.keys())[0]}</td>"
            f"<td>{shift.start_time.strftime('%H:%M')}</td>"
            f"<td>{shift.end_time.strftime('%H:%M')}</td>"
            f"<td>{shift.hours_worked} hours</td>"
            f"<td>{shift.hours_breakdown['regular']}</td>"
            f"<td>{shift.hours_breakdown['overtime_125']}</td>"
            f"<td>{shift.hours_breakdown['overtime_150']}</td>"
            f"<td>{shift_earnings['regular_earnings']:.2f} Shekels</td>"
            f"<td>{shift_earnings['overtime_125_earnings']:.2f} Shekels</td>"
            f"<td>{shift_earnings['overtime_150_earnings']:.2f} Shekels</td>"
            f"</tr>"
        )
    else:
        html_table += f"<tr><td colspan='11'>{shift.date}, No work on this day</td></tr>"

# Calculate monthly earnings
monthly_earnings = user.calculate_monthly_earnings()
html_table += (
    f"</tbody>"
    f"<tfoot>"
        f"<tr>"
            f"<td colspan='5'>Total Earnings</td>"
            f"<td>{monthly_earnings['regular']:.2f} Shekels</td>"
            f"<td>{monthly_earnings['overtime_125']:.2f} Shekels</td>"
            f"<td>{monthly_earnings['overtime_150']:.2f} Shekels</td>"
        f"</tr>"
        f"<tr>"
            f"<td colspan='5'></td>"
            f"<td colspan='3'>Total Revenue: {monthly_earnings['total']:.2f} Shekels</td>"
        f"</tr>"
    f"</tfoot>"
f"</table>"

f"</body>"
f"</html>"
)

# %%
msg = MIMEMultipart()
msg.attach(MIMEText(html_table, 'html'))

sender_email = username
sender_password = password

email_content = f"Subject: Monthly Earnings Report\n\n{html_table}"
receiver_email = username
msg['From'] = sender_email
msg['To'] = receiver_email
msg['Subject'] = 'Monthly Earnings Report'

with smtplib.SMTP('smtp.gmail.com', 587) as server:
    server.starttls()
    server.login(sender_email, sender_password)
    
    # Send the email
    server.sendmail(sender_email, receiver_email, msg.as_string())

# %%
print(monthly_earnings)
# Out:
# {'regular': 6696.0, 'overtime_125': 1193.33, 'overtime_150': 436.0, 'total': 8325.33}
